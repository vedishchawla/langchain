# %% [markdown]
# ### model integration like groq gemini gpt

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GEMINI_API_KEY"]=os.getenv("GEMINI_API_KEY")

# %%
from langchain_core.messages.block_translators import google_genai
from langchain_core.prompts import message
from langchain.chat_models import init_chat_model

model = init_chat_model(model="google_genai:gemini-2.5-flash-lite")
model
# Out:
# ChatGoogleGenerativeAI(metadata={'lc_versions': {'langchain-core': '1.4.7', 'langchain': '1.3.9'}}, output_version=None, profile={'name': 'Gemini 2.5 Flash-Lite', 'release_date': '2025-06-17', 'last_updated': '2025-06-17', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x12e34e150>, default_metadata=(), model_kwargs={})

# %%
response = model.invoke("Hello how are u give a short brief abotu java script")
response
# Out:
# AIMessage(content="Hello! I'm doing great, thanks for asking!\n\nHere's a short brief about JavaScript:\n\n**JavaScript is a versatile, high-level programming language primarily used for making web pages interactive and dynamic.** It runs directly in the user's web browser, allowing you to:\n\n*   **Manipulate web page content:** Change text, images, and styles on the fly.\n*   **Respond to user actions:** Handle clicks, form submissions, and other events.\n*   **Communicate with servers:** Fetch data without reloading the entire page (AJAX).\n*   **Create animations and games.**\n*   **Build complex web applications.**\n\nBeyond the browser, JavaScript has also expanded into server-side development (Node.js), mobile apps, and even desktop applications, making it one of the most popular and essential languages for modern software development.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019ed696-e0c7-7e50-a05c-386f5eee9290-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 179, 'total_tokens': 192, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# Hello! I'm doing great, thanks for asking!
#
# Here's a short brief about JavaScript:
#
# **JavaScript is a versatile, high-level programming language primarily used for making web pages interactive and dynamic.** It runs directly in the user's web browser, allowing you to:
#
# *   **Manipulate web page content:** Change text, images, and styles on the fly.
# *   **Respond to user actions:** Handle clicks, form submissions, and other events.
# *   **Communicate with servers:** Fetch data without reloading the entire page (AJAX).
# *   **Create animations and games.**
# *   **Build complex web applications.**
#
# Beyond the browser, JavaScript has also expanded into server-side development (Node.js), mobile apps, and even desktop applications, making it one of the most popular and essential languages for modern software development.

# %% [markdown]
# ### GROQ NOW

# %%
model = init_chat_model(model="groq:llama-3.1-8b-instant")
response = model.invoke("Hell tell me about javascript")
print(response.content)
# Out:
# **JavaScript: A Comprehensive Overview**
# =====================================================
#
# JavaScript is a high-level, dynamic, and interpreted programming language that is primarily used for client-side scripting on the web. It was created by Brendan Eich in 1995 while he was working at Netscape Communications. JavaScript is now a cornerstone technology in web development, allowing developers to create interactive and dynamic web pages.
#
# **Key Features of JavaScript**
# -------------------------------
#
# *   **Client-side scripting**: JavaScript is executed on the client's web browser, making it a key player in creating interactive web pages.
# *   **Dynamic**: JavaScript can change the content of a web page after it has been loaded.
# *   **Interpreted**: JavaScript code is executed line by line, rather than being compiled beforehand.
# *   **Object-oriented**: JavaScript supports object-oriented programming concepts such as encapsulation, inheritance, and polymorphism.
# *   **First-class functions**: Functions in JavaScript are treated as first-class citizens, meaning they can be passed around like any other variable.
#
# **JavaScript Applications**
# ---------------------------
#
# *   **Web development**: JavaScript is used for client-side scripting in web applications, allowing developers to create interactive web pages.
# *   **Mobile app development**: JavaScript is used for developing mobile applications using frameworks like React Native and PhoneGap.
# *   **Game development**: JavaScript is used for developing games using frameworks like Phaser and Pixi.js.
# *   **Server-side programming**: JavaScript is used for server-side programming using technologies like Node.js and Express.js.
#
# **Popular JavaScript Frameworks and Libraries**
# ---------------------------------------------
#
# *   **React**: A popular JavaScript library for building user interfaces.
# *   **Angular**: A JavaScript framework for building complex web applications.
# *   **Vue.js**: A progressive and flexible JavaScript framework for building web applications.
# *   **jQuery**: A popular JavaScript library for simplifying client-side scripting.
# *   **Lodash**: A JavaScript library for performing functional programming tasks.
#
# **JavaScript Syntax**
# ---------------------
#
# JavaScript syntax is composed of the following elements:
#
# *   **Variables**: Variables are used to store values in JavaScript.
# *   **Data types**: JavaScript has several built-in data types, including numbers, strings, booleans, and objects.
# *   **Operators**: JavaScript has various operators for performing arithmetic, comparison, and logical operations.
# *   **Control structures**: JavaScript has several control structures, including if-else statements, loops, and switch statements.
# *   **Functions**: Functions are used to group a set of statements together to perform a specific task.
#
# **Common JavaScript Functions**
# ------------------------------
#
# *   **console.log()**: A function for printing output to the console.
# *   **alert()**: A function for displaying an alert box to the user.
# *   **prompt()**: A function for prompting the user for input.
# *   **confirm()**: A function for displaying a confirmation box to the user.
# *   **setTimeout()**: A function for scheduling a function to be executed after a specified delay.
#
# **Best Practices for Writing JavaScript Code**
# ---------------------------------------------
#
# *   **Use meaningful variable names**: Use descriptive variable names to make your code easier to understand.
# *   **Use comments**: Use comments to explain the purpose of your code.
# *   **Use functions**: Use functions to group a set of statements together to perform a specific task.
# *   **Avoid global variables**: Avoid using global variables to prevent naming conflicts.
# *   **Use a consistent coding style**: Use a consistent coding style throughout your codebase.
#
# **Conclusion**
# ----------
#
# JavaScript is a powerful and flexible programming language that is widely used in web development. Its versatility and popularity make it a key tool for developers to create interactive and dynamic web applications. By understanding JavaScript syntax, frameworks, and best practices, developers can build robust and efficient web applications.
